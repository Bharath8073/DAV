# %%
import pandas as pd

# %%
data= {
    "Student_ID": [101,102,103,104,105,106,102,107],
    "Student": ["Asha","Ravi","Priya","John","Anu","Kiran","Ravi","Meena"],
    "Department": ["CSE","CSE","ECE","ECE","CSE","EEE","CSE","EEE"],
    "Attendence": [90,75,95,60,80,70,75,85],
    "Internal_marks": [89,87,85,78,88,98,96,77],
    "Final_marks" :[88,89,98,92,90,88,89,91]
}

# %%
df=pd.DataFrame(data)
df.to_csv("students.csv",index=False)
print("students.csv created successfully!")
# Out:
# students.csv created successfully!

# %%
df=pd.read_csv("students.csv")
print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#    Student_ID Student Department  Attendence  Internal_marks  Final_marks
# 0         101    Asha        CSE          90              89           88
# 1         102    Ravi        CSE          75              87           89
# 2         103   Priya        ECE          95              85           98
# 3         104    John        ECE          60              78           92
# 4         105     Anu        CSE          80              88           90
# 5         106   Kiran        EEE          70              98           88
# 6         102    Ravi        CSE          75              96           89
# 7         107   Meena        EEE          85              77           91

# %%
print("\nLast Five Records:")
print(df.head())
# Out:
# Last Five Records:
#    Student_ID Student Department  Attendence  Internal_marks  Final_marks
# 0         101    Asha        CSE          90              89           88
# 1         102    Ravi        CSE          75              87           89
# 2         103   Priya        ECE          95              85           98
# 3         104    John        ECE          60              78           92
# 4         105     Anu        CSE          80              88           90

# %%
print(df.tail())
# Out:
#    Student_ID Student Department  Attendence  Internal_marks  Final_marks
# 3         104    John        ECE          60              78           92
# 4         105     Anu        CSE          80              88           90
# 5         106   Kiran        EEE          70              98           88
# 6         102    Ravi        CSE          75              96           89
# 7         107   Meena        EEE          85              77           91

# %%
print(df.shape)
# Out:
# (8, 6)
