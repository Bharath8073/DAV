# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.4 MB 6.5 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.4 MB 8.0 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.4 MB 7.0 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.4 MB 6.6 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.4 MB 6.6 MB/s eta 0:00:01
#    ------------------------------------- -- 7.9/8.4 MB 6.5 MB/s eta 0:00:01
#    -------------------------------------- - 8.1/8.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 5.7 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/37.4 MB ? eta -:--:--
#     --------------------------------------- 0.8/37.4 MB 4.8 MB/s eta 0:00:08
#    -- ------------------------------------- 2.1/37.4 MB 5.6 MB/s eta 0:00:07
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.DataFrame({
    "Marks": [80,70,None,90,60],
    "Attandence": [90,None,85,88,75],
    "Department": ["CSE","ECE","CSE",None,"ECE"]
})

# %%
#filling missing catagory value using none
df["Marks"] =df["Marks"].fillna(df["Marks"].mean())

# %%
df["Attandence"] =df["Attandence"].fillna(df["Attandence"].median())

# %%
df["Department"] =df["Department"].fillna(df["Department"].mode()[0])

# %%
encoder = LabelEncoder()
df["Department"] = encoder.fit_transform(df["Department"])
print(df)
# Out:
#    Marks  Attandence  Department
# 0   80.0        90.0           0
# 1   70.0        84.5           1
# 2   75.0        85.0           0
# 3   90.0        88.0           2
# 4   60.0        75.0           1

# %%
df["Marks"].value_counts().plot(kind='bar', color=['red', 'yellow'])

plt.title('Diabetes Distribution')
plt.xlabel('Diabetes (0 = No, 1 = Yes)')
plt.ylabel('Number of People')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 df["Marks"].value_counts().plot(kind='bar', color=['red', 'yellow'])
#       2
# ----> 3 plt.title('Diabetes Distribution')
#       4 plt.xlabel('Diabetes (0 = No, 1 = Yes)')
#       5 plt.ylabel('Number of People')
#       6 plt.show()
#
# NameError: name 'plt' is not defined
